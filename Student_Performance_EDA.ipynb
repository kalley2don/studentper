# %% [markdown]
# **EDA Student Performance Indicator**

# %% [markdown]
# 1) Problem Statement

# %% [markdown]
# - This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.

# %% [markdown]
# 2) Data Collection
# - Dataset Source : https://www.kaggle.com/datasets/spscientist/students-performance-in-exams
# - The data consists of 8 columns and 1000 rows.

# %% [markdown]
# 3) Dataset Information
# - gender : ->(Male/Female)
# - race/ethnicity : ethnicity of students -> (Group A,B,C,D,E)
# - parental level of education : parent's final education -> (bachelor's degree, some college, master's degree, associate's degree, high school)
# - lunch : having lunch before test(standard or free/reduced)
# - test preparation course : complete or not complete before test
# - math score
# - reading score
# - writing score

# %% [markdown]
# Step 1 : Import all the required libraries

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Step 2 : Read the dataset

# %%
# Loading the dataset
df = pd.read_csv('stud.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# Data Checks to Perform
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of dataset
# - Check various categories present in different categorical column

# %%
df.isnull()

# %%
df.isnull().sum()

# %% [markdown]
# Data Science Life Cycle
# - Data Collection (Manually, APIs, Database, Scraping, etc)
# - Data Loading
# - Data Cleaning
# - Feature Engineering
# - EDA
# - Input and Output Feature
# - Train Test Split
# - Model Training
# - Model Evaluate
# - Hyperparameter Tuning
# - Deployment

# %%
df.isna().sum()

# %%
df.notna().sum()

# %% [markdown]
# Insight or Observation
# - There are no missing values.

# %%
df.duplicated()

# %%
df.duplicated().sum()

# %% [markdown]
# Insight or Observation
# - There are no duplicate values in the dataset.

# %%
df.dtypes

# %%
df.info()

# %%
df.nunique()

# %%
df['race/ethnicity'].unique()

# %%
df['lunch'].unique()

# %%
df['gender'].unique()

# %%
df.describe()

# %% [markdown]
# Observation:
# - From the above description of numerical data, all means are very close to each other - between 66.089 and 69.169.
# - All the standard deviation are also close - between 14.6 and 15.19.
# - While there is a minimum of 0 for maths, other are having 17 and 10 value.

# %%
df.head()

# %%
df.head(60)

# %%
df.tail()

# %%
df.tail(100)

# %%
df.columns

# %%
df.index

# %%
df.values

# %%
df.columns

# %%
for feature in df.columns:
    print(feature)

# %%
[feature for feature in df.columns]

# %%
df.dtypes

# %%
df['gender'].dtype

# %%
df['gender'].dtype == 'O'

# %%
df['writing score'].dtype == 'O'

# %%
df['gender'].dtype != 'O'

# %%
df['gender'].dtype == 'O'

# %%
df.columns

# %%
for feature in df.columns:
    if df[feature].dtype == 'object':
        print(feature)

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numerical_feature

# %%
categorical_feature

# %%
df.dtypes

# %%
categorical_feature

# %%
df['gender'].value_counts()

# %%
518/(518+482) * 100

# %%
482/(518+482) * 100

# %% [markdown]
# Observation
# - The dataset is balanced in the gender column.

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['average_score'] = df['total_score'] / 3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# 4          229      76.333333

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplots(1, 2, figsize = (15,7))
plt.subplot(1,2,1)
sns.histplot(df, x = 'average_score', bins = 40, kde = True, color = 'g')
plt.subplot(1,2,2)
sns.histplot(df, x = 'average_score', bins = 40, kde = True, hue = 'gender')
plt.show()

# %% [markdown]
# **Insights**
# - Female students tends to perform well than male students

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                       int64
# reading score                    int64
# writing score                    int64
# total_score                      int64
# average_score                  float64
# dtype: object

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(1,3,1)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'lunch')
plt.subplot(1,3,2)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'lunch')
plt.subplot(1,3,3)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'lunch')
plt.show()

# %% [markdown]
# **Insights**
# - Standard Lunch help students perform well in exams.
# - Standard lunch helps perform well in exams be it a male or female.

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# 4          229      76.333333

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'parental level of education')
plt.subplot(132)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'parental level of education')
plt.subplot(133)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'parental level of education')
plt.show()

# %% [markdown]
# Observation :
# - In general parent's education don't help student perform well in exam.
# - 3rd plot shows that parents whose education is of associate degree or master's degree their male child tend to perform well in exam.
# - 2nd plot shows that there is no effect of parent's education on female students.

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# 4          229      76.333333

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'race/ethnicity')
plt.subplot(132)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'race/ethnicity')
plt.subplot(133)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'race/ethnicity')
plt.show()

# %% [markdown]
# Observation :
# - Students of group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female.

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'test preparation course')
plt.subplot(132)
sns.histplot(data = df[df['gender'] == 'female'], x = 'average_score', kde = True, hue = 'test preparation course')
plt.subplot(133)
sns.histplot(data = df[df['gender'] == 'male'], x = 'average_score', kde = True, hue = 'test preparation course')
plt.show()

# %% [markdown]
# Observation :
# - Students who complete the test preparation course have high chance of securing good score in exam.

# %%
plt.subplots(1, 3, figsize = (25, 6))
plt.subplot(131)
sns.histplot(data = df, x = 'average_score', kde = True, hue = 'test preparation course')
plt.subplot(132)
sns.histplot(data = df[df['lunch'] == 'standard'], x = 'average_score', kde = True, hue = 'test preparation course')
plt.subplot(133)
sns.histplot(data = df[df['lunch'] == 'free/reduced'], x = 'average_score', kde = True, hue = 'test preparation course')
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      total_score  average_score
# 0            218      72.666667
# 1            247      82.333333
# 2            278      92.666667
# 3            148      49.333333
# 4            229      76.333333
# ..           ...            ...
# 995          282      94.000000
# 996          172      57.333333
# 997          195      65.000000
# 998          223      74.333333
# 999          249      83.000000
#
# [1000 rows x 10 columns]

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.corr()
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'female'

# %%
numeric_df = df.select_dtypes(include=[np.number])
numeric_df.head()
# Out:
#    math score  reading score  writing score  total_score  average_score
# 0          72             72             74          218      72.666667
# 1          69             90             88          247      82.333333
# 2          90             95             93          278      92.666667
# 3          47             57             44          148      49.333333
# 4          76             78             75          229      76.333333

# %%
numeric_df.corr()
# Out:
#                math score  reading score  writing score  total_score  \
# math score       1.000000       0.817580       0.802642     0.918746
# reading score    0.817580       1.000000       0.954598     0.970331
# writing score    0.802642       0.954598       1.000000     0.965667
# total_score      0.918746       0.970331       0.965667     1.000000
# average_score    0.918746       0.970331       0.965667     1.000000
#
#                average_score
# math score          0.918746
# reading score       0.970331
# writing score       0.965667
# total_score         1.000000
# average_score       1.000000

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot = True)
# Out:
# <Axes: >
