# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (8,5)

# %%
df = pd.read_csv('callcenter.csv')

# %%
file_path = 'D:/EDA/callcenter.csv'

# %%
df.head()
# Out:
#          Date          Agent Name Call Type  \
# 0  12/16/2024  Kshitiz Kamu Magar        IN
# 1  12/16/2024  Kshitiz Kamu Magar        IN
# 2  12/16/2024        Suraj Khaiju        IN
# 3  12/16/2024      Bipul Shrestha        IN
# 4  12/16/2024  Kshitiz Kamu Magar        IN
#
#                                         Client Name       Number  \
# 0                  NIC-Asia-Laghubitta-Baddichaur-SM  9848138665
# 1  Jalpa-Laghubitta-Bitiya-Sanstha-Krishnapur-Kan...  9810993020
# 2                         Jalpa-Pyuthan-Bhingri-FTTH  9866937146
# 3                 Global-Ime-Jogbuda-EXT-CounterFTTx  9806468191
# 4                 Global-Ime-Jogbuda-EXT-CounterFTTx  9806468191
#
#      Problem Type          escalation  Pod time/ ticket Ticket  \
# 0        Wireless                  NaN              NaN  64067
# 1  Intranet / VPN                  NaN              NaN  64068
# 2  Intranet / VPN  16-12-2024 08:41:54              NaN  64088
# ...

# %%
df
# Out:
#             Date          Agent Name Call Type  \
# 0     12/16/2024  Kshitiz Kamu Magar        IN
# 1     12/16/2024  Kshitiz Kamu Magar        IN
# 2     12/16/2024        Suraj Khaiju        IN
# 3     12/16/2024      Bipul Shrestha        IN
# 4     12/16/2024  Kshitiz Kamu Magar        IN
# ...          ...                 ...       ...
# 1369  15/01/2025                 NaN       NaN
# 1370  15/01/2025                 NaN       NaN
# 1371  15/01/2025                 NaN       NaN
# 1372  15/01/2025                 NaN       NaN
# 1373  15/01/2025                 NaN       NaN
#
#                                            Client Name       Number  \
# 0                     NIC-Asia-Laghubitta-Baddichaur-SM  9848138665
# 1     Jalpa-Laghubitta-Bitiya-Sanstha-Krishnapur-Kan...  9810993020
# 2                            Jalpa-Pyuthan-Bhingri-FTTH  9866937146
# 3                    Global-Ime-Jogbuda-EXT-CounterFTTx  9806468191
# ...

# %%
df.describe()
# Out:
#               Date       Agent Name Call Type                    Client Name   \
# count         1371             1327      1320                            1286
# unique          32               13         2                             598
# top     12/17/2024  Rebika Shrestha       OUT  Jalpa-Laghubitta-kohalabi-FTTX
# freq           100              235       737                              21
#
#             Number    Problem Type          escalation      Pod time/ ticket  \
# count         1302            1272                  582                   13
# unique         661               7                  448                   12
# top     9862317136  Intranet / VPN  26-12-2024 10:57:51  19-12-2024 12:40:01
# freq            18             882                    6                    2
#
#        Ticket   Ticket Status Department    Outbound Type   Call Source  \
# count     672            1271        996               775          927
# ...

# %%
df
# Out:
#             Date          Agent Name Call Type  \
# 0     12/16/2024  Kshitiz Kamu Magar        IN
# 1     12/16/2024  Kshitiz Kamu Magar        IN
# 2     12/16/2024        Suraj Khaiju        IN
# 3     12/16/2024      Bipul Shrestha        IN
# 4     12/16/2024  Kshitiz Kamu Magar        IN
# ...          ...                 ...       ...
# 1369  15/01/2025                 NaN       NaN
# 1370  15/01/2025                 NaN       NaN
# 1371  15/01/2025                 NaN       NaN
# 1372  15/01/2025                 NaN       NaN
# 1373  15/01/2025                 NaN       NaN
#
#                                            Client Name       Number  \
# 0                     NIC-Asia-Laghubitta-Baddichaur-SM  9848138665
# 1     Jalpa-Laghubitta-Bitiya-Sanstha-Krishnapur-Kan...  9810993020
# 2                            Jalpa-Pyuthan-Bhingri-FTTH  9866937146
# 3                    Global-Ime-Jogbuda-EXT-CounterFTTx  9806468191
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1374 entries, 0 to 1373
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1371 non-null   object
#  1   Agent Name        1327 non-null   object
#  2   Call Type         1320 non-null   object
#  3   Client Name       1286 non-null   object
#  4   Number            1302 non-null   object
#  5   Problem Type      1272 non-null   object
#  6   escalation        582 non-null    object
#  7   Pod time/ ticket  13 non-null     object
#  8   Ticket            672 non-null    object
#  9   Ticket Status     1271 non-null   object
#  10  Department        996 non-null    object
#  11  Outbound Type     775 non-null    object
#  12  Call Source       927 non-null    object
#  13  Remarks           169 non-null    object
# dtypes: object(14)
# memory usage: 150.4+ KB

# %%
df['Call Source'].value_counts()
# Out:
# Call Source
# NGUCC Panel    830
# X-Lite          92
# Telephone        5
# Name: count, dtype: int64

# %%
sns.histplot(df['Call Source'], kde=True)
plt.title('Distribution of Call Source')
plt.show()

# %%
sns.countplot(x='Agent Name', data=df)
plt.title('Distribution of Agent Name')
plt.show()

# %%
df['Agent Name'].value_counts()
# Out:
# Agent Name
# Rebika Shrestha       235
# Nikita Shrestha       187
# Ruksana Shrestha      173
# Hari Dahal            163
# Yagesh KC             155
# Kshitiz Kamu Magar    116
# Anmol Shrestha         99
# Suraj Khaiju           85
# Gaurab Sapkota         33
# Nirajan Chaudhary      31
# Bipul Shrestha         25
# Nitesh Pokhrel         16
# Sagar Bhattarai         9
# Name: count, dtype: int64
